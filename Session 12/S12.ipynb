# %%
# !git clone https://github.com/TharunSivamani/Pytorch.git

# %cd Pytorch/Lightning/

# !pip install -qr requirements.txt
# Out:
# Cloning into 'Pytorch'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 72 (delta 24), reused 50 (delta 7), pack-reused 0
# Receiving objects: 100% (72/72), 20.68 KiB | 4.14 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# /content/Pytorch/Lightning
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 51.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.8/722.8 kB 26.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.1/731.1 kB 32.6 MB/s eta 0:00:00
#   Building wheel for grad-cam (pyproject.toml) ... done

# %%
from main import *
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:13<00:00, 13056425.99it/s]
# Extracting data/cifar-10-python.tar.gz to data/
# Files already downloaded and verified
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: tb_logs/cifar10_model_v0
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 1.63E-04
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name           | Type             | Params
# ----------------------------------------------------
# 0 | network        | Sequential       | 6.6 M
# 1 | criterion      | CrossEntropyLoss | 0
# 2 | train_accuracy | MyAccuracy       | 0
# 3 | val_accuracy   | MyAccuracy       | 0
# 4 | train_loss     | MeanMetric       | 0
# 5 | val_loss       | MeanMetric       | 0
# ----------------------------------------------------
# 6.6 M     Trainable params
# 0         Non-trainable params
# 6.6 M     Total params
# 26.301    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Epoch: 1, Valid: Loss: 2.3115, Accuracy: 8.98
# Starting to train!
# Training: 0it [00:00, ?it/s]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Validation: 0it [00:00, ?it/s]
# Epoch: 1, Valid: Loss: 1.6160, Accuracy: 41.78
# Epoch: 1, Train: Loss: 2.4640, Accuracy: 24.90
# Validation: 0it [00:00, ?it/s]
# Epoch: 2, Valid: Loss: 1.2848, Accuracy: 54.11
# Epoch: 2, Train: Loss: 1.4931, Accuracy: 46.05
# Validation: 0it [00:00, ?it/s]
# Epoch: 3, Valid: Loss: 1.0907, Accuracy: 61.53
# Epoch: 3, Train: Loss: 1.2493, Accuracy: 55.19
# Validation: 0it [00:00, ?it/s]
# Epoch: 4, Valid: Loss: 0.9318, Accuracy: 66.98
# Epoch: 4, Train: Loss: 1.0785, Accuracy: 61.95
# Validation: 0it [00:00, ?it/s]
# Epoch: 5, Valid: Loss: 0.8031, Accuracy: 71.38
# Epoch: 5, Train: Loss: 0.9371, Accuracy: 66.88
# Validation: 0it [00:00, ?it/s]
# Epoch: 6, Valid: Loss: 0.7004, Accuracy: 75.21
# Epoch: 6, Train: Loss: 0.8215, Accuracy: 71.31
# Validation: 0it [00:00, ?it/s]
# Epoch: 7, Valid: Loss: 0.6789, Accuracy: 76.61
# Epoch: 7, Train: Loss: 0.7294, Accuracy: 74.41
# Validation: 0it [00:00, ?it/s]
# Epoch: 8, Valid: Loss: 0.6587, Accuracy: 77.19
# Epoch: 8, Train: Loss: 0.6624, Accuracy: 76.70
# Validation: 0it [00:00, ?it/s]
# Epoch: 9, Valid: Loss: 0.5492, Accuracy: 80.65
# Epoch: 9, Train: Loss: 0.6013, Accuracy: 79.09
# Validation: 0it [00:00, ?it/s]
# Epoch: 10, Valid: Loss: 0.5067, Accuracy: 82.77
# Epoch: 10, Train: Loss: 0.5598, Accuracy: 80.56
# Validation: 0it [00:00, ?it/s]
# Epoch: 11, Valid: Loss: 0.5257, Accuracy: 81.93
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#               ReLU-9          [-1, 128, 16, 16]               0
#           Dropout-10          [-1, 128, 16, 16]               0
#   DownsampleLayer-11          [-1, 128, 16, 16]               0
#            Conv2d-12          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-13          [-1, 128, 16, 16]             256
#              ReLU-14          [-1, 128, 16, 16]               0
#           Dropout-15          [-1, 128, 16, 16]               0
#         ConvBlock-16          [-1, 128, 16, 16]               0
#            Conv2d-17          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#              ReLU-19          [-1, 128, 16, 16]               0
#           Dropout-20          [-1, 128, 16, 16]               0
#         ConvBlock-21          [-1, 128, 16, 16]               0
#     ResidualBlock-22          [-1, 128, 16, 16]               0
#         MakeLayer-23          [-1, 128, 16, 16]               0
#            Conv2d-24          [-1, 256, 16, 16]         295,168
#         MaxPool2d-25            [-1, 256, 8, 8]               0
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#              ReLU-27            [-1, 256, 8, 8]               0
#           Dropout-28            [-1, 256, 8, 8]               0
#   DownsampleLayer-29            [-1, 256, 8, 8]               0
#         MakeLayer-30            [-1, 256, 8, 8]               0
#            Conv2d-31            [-1, 512, 8, 8]       1,180,160
#         MaxPool2d-32            [-1, 512, 4, 4]               0
#       BatchNorm2d-33            [-1, 512, 4, 4]           1,024
#              ReLU-34            [-1, 512, 4, 4]               0
#           Dropout-35            [-1, 512, 4, 4]               0
#   DownsampleLayer-36            [-1, 512, 4, 4]               0
#            Conv2d-37            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#              ReLU-39            [-1, 512, 4, 4]               0
#           Dropout-40            [-1, 512, 4, 4]               0
#         ConvBlock-41            [-1, 512, 4, 4]               0
#            Conv2d-42            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-43            [-1, 512, 4, 4]           1,024
#              ReLU-44            [-1, 512, 4, 4]               0
#           Dropout-45            [-1, 512, 4, 4]               0
#         ConvBlock-46            [-1, 512, 4, 4]               0
#     ResidualBlock-47            [-1, 512, 4, 4]               0
#         MakeLayer-48            [-1, 512, 4, 4]               0
#         MaxPool2d-49            [-1, 512, 1, 1]               0
#           Flatten-50                  [-1, 512]               0
#            Linear-51                   [-1, 10]           5,130
# ================================================================
# Total params: 6,575,370
# Trainable params: 6,575,370
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 10.32
# Params size (MB): 25.08
# Estimated Total Size (MB): 35.42
# ----------------------------------------------------------------

# %%
results = trainer.predict(model,dataloaders=dm.test_dataloader())
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 0it [00:00, ?it/s]

# %%
misclassified_images, predictions, labels = [], [], []

for result in results:
    misclassified_images.extend(result[0])
    predictions.extend(result[1])
    labels.extend(result[2])

# %%
plot_images(misclassified_images,predictions,labels,classes = CLASSES)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
display_gradCam(misclassified_images, predictions, labels,target_layer=model.network[3],classes=CLASSES,model=model)

# %%
download_misclassified_images(misclassified_images,ind=100)

# %%
csv_final = download_csv(labels,predictions,ind=100)
csv_final.to_csv("s12_final.csv")

# %%
import torch

# %%
torch.save(model.state_dict(), 's12_model.pth')

# %%
import shutil

# Folder path you want to download
folder_path = '/content/Pytorch/Lightning/incorrect'

# Zip the folder
shutil.make_archive('/content/Pytorch/Lightning/incorrect', 'zip', folder_path)

# Move the ZIP file to a downloadable location
shutil.move('/content/Pytorch/Lightning/incorrect.zip', '/content/Pytorch/Lightning/incorrect/incorrect.zip')
# Out:
# '/content/Pytorch/Lightning/incorrect/incorrect.zip'
