# %%
# !git clone https://github.com/TharunSivamani/Pytorch.git
# %cd Pytorch/Unet/
# Out:
# Cloning into 'Pytorch'...
# remote: Enumerating objects: 518, done.
# remote: Counting objects: 100% (518/518), done.
# remote: Compressing objects: 100% (475/475), done.
# remote: Total 518 (delta 76), reused 462 (delta 25), pack-reused 0
# Receiving objects: 100% (518/518), 17.04 MiB | 19.83 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# /content/Pytorch/Unet

# %%
# !pip install -r requirements.txt --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.7/727.7 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.8/764.8 kB 58.0 MB/s eta 0:00:00

# %%
from main import *
# Out:
# Downloading https://thor.robots.ox.ac.uk/datasets/pets/images.tar.gz to data/oxford-iiit-pet/images.tar.gz
# 100%|██████████| 791918971/791918971 [00:32<00:00, 24504161.25it/s]
# Extracting data/oxford-iiit-pet/images.tar.gz to data/oxford-iiit-pet
# Downloading https://thor.robots.ox.ac.uk/datasets/pets/annotations.tar.gz to data/oxford-iiit-pet/annotations.tar.gz
# 100%|██████████| 19173078/19173078 [00:01<00:00, 10110986.09it/s]
# Extracting data/oxford-iiit-pet/annotations.tar.gz to data/oxford-iiit-pet

# %%
visualise_data(dm.train_ds)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
unet_model = UNet(3, 3).to("cuda")
summary(unet_model, (3,128,128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           1,792
#        BatchNorm2d-2         [-1, 64, 128, 128]             128
#               ReLU-3         [-1, 64, 128, 128]               0
#             Conv2d-4         [-1, 64, 128, 128]          36,928
#        BatchNorm2d-5         [-1, 64, 128, 128]             128
#               ReLU-6         [-1, 64, 128, 128]               0
#          MaxPool2d-7           [-1, 64, 64, 64]               0
#   ContractingBlock-8  [[-1, 64, 64, 64], [-1, 64, 128, 128]]               0
#             Conv2d-9          [-1, 128, 64, 64]          73,856
#       BatchNorm2d-10          [-1, 128, 64, 64]             256
#              ReLU-11          [-1, 128, 64, 64]               0
#            Conv2d-12          [-1, 128, 64, 64]         147,584
#       BatchNorm2d-13          [-1, 128, 64, 64]             256
#              ReLU-14          [-1, 128, 64, 64]               0
#         MaxPool2d-15          [-1, 128, 32, 32]               0
#  ContractingBlock-16  [[-1, 128, 32, 32], [-1, 128, 64, 64]]               0
#            Conv2d-17          [-1, 256, 32, 32]         295,168
#       BatchNorm2d-18          [-1, 256, 32, 32]             512
#              ReLU-19          [-1, 256, 32, 32]               0
#            Conv2d-20          [-1, 256, 32, 32]         590,080
#       BatchNorm2d-21          [-1, 256, 32, 32]             512
#              ReLU-22          [-1, 256, 32, 32]               0
#         MaxPool2d-23          [-1, 256, 16, 16]               0
#  ContractingBlock-24  [[-1, 256, 16, 16], [-1, 256, 32, 32]]               0
#            Conv2d-25          [-1, 512, 16, 16]       1,180,160
#       BatchNorm2d-26          [-1, 512, 16, 16]           1,024
#              ReLU-27          [-1, 512, 16, 16]               0
#            Conv2d-28          [-1, 512, 16, 16]       2,359,808
#       BatchNorm2d-29          [-1, 512, 16, 16]           1,024
#              ReLU-30          [-1, 512, 16, 16]               0
#         MaxPool2d-31            [-1, 512, 8, 8]               0
#  ContractingBlock-32  [[-1, 512, 8, 8], [-1, 512, 16, 16]]               0
#   ConvTranspose2d-33          [-1, 256, 32, 32]         524,544
#            Conv2d-34          [-1, 256, 32, 32]       1,179,904
#       BatchNorm2d-35          [-1, 256, 32, 32]             512
#              ReLU-36          [-1, 256, 32, 32]               0
#            Conv2d-37          [-1, 256, 32, 32]         590,080
#       BatchNorm2d-38          [-1, 256, 32, 32]             512
#              ReLU-39          [-1, 256, 32, 32]               0
#    ExpandingBlock-40          [-1, 256, 32, 32]               0
#   ConvTranspose2d-41          [-1, 128, 64, 64]         131,200
#            Conv2d-42          [-1, 128, 64, 64]         295,040
#       BatchNorm2d-43          [-1, 128, 64, 64]             256
#              ReLU-44          [-1, 128, 64, 64]               0
#            Conv2d-45          [-1, 128, 64, 64]         147,584
#       BatchNorm2d-46          [-1, 128, 64, 64]             256
#              ReLU-47          [-1, 128, 64, 64]               0
#    ExpandingBlock-48          [-1, 128, 64, 64]               0
#   ConvTranspose2d-49         [-1, 64, 128, 128]          32,832
#            Conv2d-50         [-1, 64, 128, 128]          73,792
#       BatchNorm2d-51         [-1, 64, 128, 128]             128
#              ReLU-52         [-1, 64, 128, 128]               0
#            Conv2d-53         [-1, 64, 128, 128]          36,928
#       BatchNorm2d-54         [-1, 64, 128, 128]             128
#              ReLU-55         [-1, 64, 128, 128]               0
#    ExpandingBlock-56         [-1, 64, 128, 128]               0
#            Conv2d-57          [-1, 3, 128, 128]             195
# ================================================================
# Total params: 7,703,107
# Trainable params: 7,703,107
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 2785073.88
# Params size (MB): 29.39
# Estimated Total Size (MB): 2785103.45
# ----------------------------------------------------------------

# %% [markdown]
# # MP + TR + BCE

# %%
model_1 = UNETLitModel(
    in_channels=3,
    out_channels=3,
    pool="maxpool",
    mode="transpose",
    criterion="bce"
)

# %%
runner(model_1)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/Pytorch/Unet/lightning_logs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loading `train_dataloader` to estimate number of stepping batches.
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name    | Type              | Params
# ----------------------------------------------
# 0 | net     | UNet              | 7.7 M
# 1 | loss_fn | BCEWithLogitsLoss | 0
# ----------------------------------------------
# 7.7 M     Trainable params
# 0         Non-trainable params
# 7.7 M     Total params
# 30.812    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch: 1 | Loss:  0.55748
# Epoch: 2 | Loss:  0.39606
# Epoch: 3 | Loss:  0.31384
# Epoch: 4 | Loss:  0.26941
# Epoch: 5 | Loss:  0.24721
# Epoch: 6 | Loss:  0.21944
# Epoch: 7 | Loss:  0.19933
# Epoch: 8 | Loss:  0.18236
# Epoch: 9 | Loss:  0.16754
# Epoch: 10 | Loss:  0.1544
# Epoch: 11 | Loss:  0.14948
# Epoch: 12 | Loss:  0.14522
# Epoch: 13 | Loss:  0.14091
# Epoch: 14 | Loss:  0.13709
# Epoch: 15 | Loss:  0.13483
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=15` reached.

# %%
model_1.plot_train_loss()

# %%
model_1 = model_1.to("cuda")
visualise_model_outputs(model_1, test_loader, 3)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # MP + TR + Dice Loss

# %%
model_2 = UNETLitModel(
    in_channels=3,
    out_channels=3,
    pool="maxpool",
    mode="transpose",
    criterion="dice"
)

# %%
runner(model_2)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loading `train_dataloader` to estimate number of stepping batches.
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name    | Type     | Params
# -------------------------------------
# 0 | net     | UNet     | 7.7 M
# 1 | loss_fn | DiceLoss | 0
# -------------------------------------
# 7.7 M     Trainable params
# 0         Non-trainable params
# 7.7 M     Total params
# 30.812    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch: 1 | Loss:  -0.92225
# Epoch: 2 | Loss:  -2.95187
# Epoch: 3 | Loss:  0.60851
# Epoch: 4 | Loss:  0.87842
# Epoch: 5 | Loss:  0.24448
# Epoch: 6 | Loss:  -0.61579
# Epoch: 7 | Loss:  -1.38141
# Epoch: 8 | Loss:  0.9956
# Epoch: 9 | Loss:  0.88031
# Epoch: 10 | Loss:  0.85942
# Epoch: 11 | Loss:  0.85478
# Epoch: 12 | Loss:  0.84699
# Epoch: 13 | Loss:  0.84068
# Epoch: 14 | Loss:  0.84056
# Epoch: 15 | Loss:  0.83796
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=15` reached.

# %%
model_2.plot_train_loss()

# %%
model_2 = model_2.to("cuda")
visualise_model_outputs(model_2, test_loader, 3)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # StrConv + TR + BCE

# %%
model_3 = UNETLitModel(
    in_channels=3,
    out_channels=3,
    pool="strided_conv",
    mode="transpose",
    criterion="bce"
)

# %%
runner(model_3)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loading `train_dataloader` to estimate number of stepping batches.
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name    | Type              | Params
# ----------------------------------------------
# 0 | net     | UNet              | 9.1 M
# 1 | loss_fn | BCEWithLogitsLoss | 0
# ----------------------------------------------
# 9.1 M     Trainable params
# 0         Non-trainable params
# 9.1 M     Total params
# 36.387    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch: 1 | Loss:  0.54972
# Epoch: 2 | Loss:  0.3991
# Epoch: 3 | Loss:  0.31784
# Epoch: 4 | Loss:  0.28277
# Epoch: 5 | Loss:  0.25184
# Epoch: 6 | Loss:  0.22848
# Epoch: 7 | Loss:  0.2052
# Epoch: 8 | Loss:  0.18789
# Epoch: 9 | Loss:  0.1709
# Epoch: 10 | Loss:  0.16047
# Epoch: 11 | Loss:  0.15483
# Epoch: 12 | Loss:  0.15007
# Epoch: 13 | Loss:  0.14655
# Epoch: 14 | Loss:  0.14274
# Epoch: 15 | Loss:  0.14042
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=15` reached.

# %%
model_3.plot_train_loss()

# %%
model_3 = model_3.to("cuda")
visualise_model_outputs(model_3, test_loader, 3)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # StrConv + Ups + Dice Loss

# %%
model_4 = UNETLitModel(
    in_channels=3,
    out_channels=3,
    pool="strided_conv",
    mode="upsample",
    criterion="dice"
)

# %%
runner(model_4)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loading `train_dataloader` to estimate number of stepping batches.
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name    | Type     | Params
# -------------------------------------
# 0 | net     | UNet     | 8.6 M
# 1 | loss_fn | DiceLoss | 0
# -------------------------------------
# 8.6 M     Trainable params
# 0         Non-trainable params
# 8.6 M     Total params
# 34.322    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch: 1 | Loss:  -0.46473
# Epoch: 2 | Loss:  -43.64731
# Epoch: 3 | Loss:  -4.70358
# Epoch: 4 | Loss:  1.43692
# Epoch: 5 | Loss:  0.80297
# Epoch: 6 | Loss:  0.69426
# Epoch: 7 | Loss:  0.7072
# Epoch: 8 | Loss:  0.48834
# Epoch: 9 | Loss:  -0.08371
# Epoch: 10 | Loss:  -0.81621
# Epoch: 11 | Loss:  -0.90267
# Epoch: 12 | Loss:  -0.99429
# Epoch: 13 | Loss:  -1.08222
# Epoch: 14 | Loss:  -1.18171
# Epoch: 15 | Loss:  -1.26825
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=15` reached.

# %%
model_4.plot_train_loss()

# %%
model_4 = model_4.to("cuda")
visualise_model_outputs(model_4, test_loader, 3)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
