# %%
# !git clone https://github.com/TharunSivamani/Pytorch.git
# %cd Pytorch/Transformers
# Out:
# Cloning into 'Pytorch'...
# remote: Enumerating objects: 484, done.
# remote: Counting objects: 100% (484/484), done.
# remote: Compressing objects: 100% (446/446), done.
# remote: Total 484 (delta 62), reused 439 (delta 22), pack-reused 0
# Receiving objects: 100% (484/484), 17.04 MiB | 30.39 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# /kaggle/working/Pytorch/Transformers

# %%
from main import BERT

# %%
BERT()
# Out:
# Loading Text...
# Tokenizing sentences...
# Creating / Loading Vocab...
# Creating Dataset...
# Initializing Model...
# Initializing Optimizer and Loss...
# Starting Model Training...
# it: 0  | loss 10.22  | Δw: 1.29
# it: 10  | loss 9.56  | Δw: 0.518
# it: 20  | loss 9.32  | Δw: 0.344
# it: 30  | loss 9.18  | Δw: 0.285
# it: 40  | loss 8.98  | Δw: 0.231
# it: 50  | loss 8.83  | Δw: 0.212
# it: 60  | loss 8.72  | Δw: 0.197
# it: 70  | loss 8.58  | Δw: 0.189
# it: 80  | loss 8.33  | Δw: 0.167
# it: 90  | loss 8.23  | Δw: 0.164
# it: 100  | loss 8.05  | Δw: 0.158
# it: 110  | loss 7.92  | Δw: 0.156
# it: 120  | loss 7.8  | Δw: 0.144
# it: 130  | loss 7.64  | Δw: 0.138
# it: 140  | loss 7.48  | Δw: 0.135
# it: 150  | loss 7.41  | Δw: 0.137
# it: 160  | loss 7.24  | Δw: 0.141
# it: 170  | loss 7.23  | Δw: 0.128
# it: 180  | loss 7.1  | Δw: 0.13
# it: 190  | loss 7.01  | Δw: 0.126
# it: 200  | loss 6.86  | Δw: 0.13
# it: 210  | loss 6.89  | Δw: 0.122
# it: 220  | loss 6.79  | Δw: 0.128
# ...
