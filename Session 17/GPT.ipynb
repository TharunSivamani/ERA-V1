# %%
# !git clone https://github.com/TharunSivamani/Pytorch.git
# %cd Pytorch/Transformers
# Out:
# Cloning into 'Pytorch'...
# remote: Enumerating objects: 488, done.
# remote: Counting objects: 100% (488/488), done.
# remote: Compressing objects: 100% (449/449), done.
# remote: Total 488 (delta 64), reused 441 (delta 22), pack-reused 0
# Receiving objects: 100% (488/488), 17.04 MiB | 16.91 MiB/s, done.
# Resolving deltas: 100% (64/64), done.
# /content/Pytorch/Transformers

# %%
# !pip install -r requirements.txt --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 54.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 29.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.8 MB/s eta 0:00:00

# %%
from main import GPT

# %%
GPT()
# Out:
# Loading Text...
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (37443 > 512). Running this sequence through the model will result in indexing errors
# Train / Validation Split...
# Initializing Model...
# Model with 89.48M parameters
# Initializing Optimizer ...
# step          0 | train loss 10.6856 | val loss 10.6957
# step        500 | train loss 0.5269 | val loss 8.0400
# step       1000 | train loss 0.1659 | val loss 9.3979
# step       1500 | train loss 0.1406 | val loss 10.1811
# step       2000 | train loss 0.1274 | val loss 10.2829
# step       2500 | train loss 0.1269 | val loss 10.6556
# step       3000 | train loss 0.1191 | val loss 10.5359
# step       3500 | train loss 0.1131 | val loss 10.9533
# step       4000 | train loss 0.1119 | val loss 10.7073
# step       4500 | train loss 0.1064 | val loss 11.1684
# step       4999 | train loss 0.1006 | val loss 10.9910
# Validation....
#
#  Starting with Validation...
# [PAD] we solved the issue of large channel size by using maxpooling, but we need to figure out a way to reduce the number of channels while making sure, that, we are not defeating the purpose of increasing the number of channels ( something we desperately want ). we'll resolve this cliffhanger in the next session! fully connected layers in the image below as 7 unrolls into 28 * 28 numbers, the weights are being learned to learn a pattern in 1d unrolled array
# End
