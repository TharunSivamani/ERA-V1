# %%
# !git clone https://github.com/TharunSivamani/Pytorch.git
# %pushd Pytorch
# !git pull
# !pip install -qr requirements.txt

import warnings
warnings.filterwarnings('ignore')
# Out:
# Cloning into 'Pytorch'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 36 (delta 8), reused 24 (delta 2), pack-reused 0
# Receiving objects: 100% (36/36), 12.41 KiB | 2.07 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/Pytorch
# Already up to date.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 19.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
from main import *
# Out:
# ...
# 100%|██████████| 170498071/170498071 [00:01<00:00, 98220711.67it/s]
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
show_train_data(train_loaders , 20 , "Training Data" , classes)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
show_test_data(test_loaders , 20 , "Testing Data" , classes)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
summary(model)
# Out:
# ...
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Param %
# ...
# ResNet                                   [32, 3, 32, 32]           [32, 10]                  --                             --
# ├─Conv2d: 1-1                            [32, 3, 32, 32]           [32, 64, 32, 32]          1,728                       0.02%
# ├─BatchNorm2d: 1-2                       [32, 64, 32, 32]          [32, 64, 32, 32]          128                         0.00%
# ├─Sequential: 1-3                        [32, 64, 32, 32]          [32, 64, 32, 32]          --                             --
# │    └─BasicBlock: 2-1                   [32, 64, 32, 32]          [32, 64, 32, 32]          --                             --
# │    │    └─Conv2d: 3-1                  [32, 64, 32, 32]          [32, 64, 32, 32]          36,864                      0.33%
# ...

# %%
runner = create_runner(model, data,train_loaders , test_loaders, criterion='cross-entropy', epochs=20, scheduler="one_cyclelr")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 5.09E-03

# %%
runner.runner()
# Out:
# Epoch: 1
# Train: Average Loss: 1.61, Accuracy: 41.10 LR: 0.001059064382880664: 100%|██████████| 1563/1563 [00:57<00:00, 27.24it/s]
# Test set: Average loss: 1.24, Accuracy: 5660/10000 (56.60%)
#
# Epoch: 2
# Train: Average Loss: 1.14, Accuracy: 59.74 LR: 0.002067832790864593: 100%|██████████| 1563/1563 [00:59<00:00, 26.29it/s]
# Test set: Average loss: 1.06, Accuracy: 6320/10000 (63.20%)
#
# Epoch: 3
# Train: Average Loss: 0.93, Accuracy: 67.52 LR: 0.0030766011988485227: 100%|██████████| 1563/1563 [00:59<00:00, 26.08it/s]
# Test set: Average loss: 0.74, Accuracy: 7476/10000 (74.76%)
#
# Epoch: 4
# Train: Average Loss: 0.79, Accuracy: 72.65 LR: 0.004085369606832451: 100%|██████████| 1563/1563 [00:59<00:00, 26.25it/s]
# Test set: Average loss: 0.88, Accuracy: 7189/10000 (71.89%)
#
# Epoch: 5
# Train: Average Loss: 0.70, Accuracy: 75.78 LR: 0.0050941380148163806: 100%|██████████| 1563/1563 [00:59<00:00, 26.30it/s]
# Test set: Average loss: 0.58, Accuracy: 8052/10000 (80.52%)
#
# ...

# %%
runner.train.plot_train_stats()

# %%
runner.test.plot_test_stats()

# %%
runner.show_incorrect()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Test set: Average loss: 0.23, Accuracy: 9261/10000 (92.61%)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
plotGradCAM(model, test_loaders, classes, device)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
accuracy_class(model, classes, test_loaders)
# Out:
# Accuracy for class: plane is 94.1 %
# Accuracy for class: car   is 97.2 %
# Accuracy for class: bird  is 88.2 %
# Accuracy for class: cat   is 82.8 %
# Accuracy for class: deer  is 94.1 %
# Accuracy for class: dog   is 87.4 %
# Accuracy for class: frog  is 94.7 %
# Accuracy for class: horse is 95.5 %
# Accuracy for class: ship  is 96.3 %
# Accuracy for class: truck is 95.8 %
