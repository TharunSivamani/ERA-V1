# %%
# !git clone https://github.com/TharunSivamani/Transformers-BiLang-V2.git
# %cd Transformers-BiLang-V2
# Out:
# Cloning into 'Transformers-BiLang-V2'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 29 (delta 7), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (29/29), 13.97 KiB | 2.00 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /kaggle/working/Transformers-BiLang-V2

# %%
# !pip install -r requirements.txt --quiet

# %%
from main import *
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
runner(train=True)
# Out:
# ...
# Generating train split:   0%|          | 0/127085 [00:00<?, ? examples/s]
# Dataset opus_books downloaded and prepared to /root/.cache/huggingface/datasets/opus_books/en-fr/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf. Subsequent calls will reuse this data.
# Length of filtered dataset : 120677
# Train DS Size : 108609
#   Val DS Size : 12068
# Max length of source sentence: 150
# Max length of target sentence: 159
# Source Vocab Size : 30000
# Target Vocab Size : 30000
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 0 :
# ----------------------------------------------------------------------
# SOURCE    := If the box had fallen at this place it must have been swept away by the waves.
# EXPECTED  := Si la boîte était tombée en cet endroit, elle avait dû être entraînée par les flots.
# PREDICTED := Si la foule avait déjà pris ce moment , il faut que les eaux ont été sur les eaux .
# ...
